# %%
import matplotlib.pyplot as plt
import numpy as np
import uncertainties.unumpy as unp
from scipy import stats
from uncertainties import ufloat
from scipy.optimize import curve_fit
import scipy.constants as const

# %%
f, amp = np.genfromtxt("data/c_5_90.dat", unpack=True)

# %%
f, amp = np.genfromtxt("data/c_5_0.dat", unpack=True)
fig = plt.figure(figsize=(8,7))
ax1 = fig.add_subplot(311)
ax1.set_xlabel(r"$f$/kHz")
ax1.set_ylabel(r"Amplitude/ (a.u.)")
ax1.plot(f*1e-3, amp);

# %%
phi = np.arange(0,185,5)
linspace = np.linspace(50,150,37)
fig = plt.figure(figsize=(8,8))
fig.add_subplot(111, projection='polar')
plt.polar(phi,linspace,'.');
